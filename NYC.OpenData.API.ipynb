# %%
# make sure to install these packages before running:
# pip install pandas
# pip install sodapy
from sodapy import Socrata
import pandas as pd
import numpy as np
import requests
import json

# %%
# Enter the information from those sections here
socrata_domain = 'data.cityofnewyork.us'
socrata_dataset_identifier = 'erm2-nwe9'
socrata_token="5EDWHSfpo1f6QGvb6ddbiML17"

# %%
#API Pull Type 1: Using Socrata
client = Socrata(socrata_domain, socrata_token)
print("Domain: {domain:}\nSession: {session:}\nURI Prefix: {uri_prefix:}".format(**client.__dict__))
client.timeout=50
results = client.get(socrata_dataset_identifier)
df = pd.DataFrame.from_dict(results)
df.head()
# Out:
# Domain: data.cityofnewyork.us
# Session: <requests.sessions.Session object at 0x000001D52B804358>
# URI Prefix: https://

# %%
#API Type 2: Using .Get on a base URL with SoQL query code 
base_url = "https://data.cityofnewyork.us/resource/erm2-nwe9.json?$$app_token=5EDWHSfpo1f6QGvb6ddbiML17&$where=created_date between '2019-01-01T20:00:00' and '2019-12-01T23:59:59'"
response = requests.get(base_url).json()
df_r = pd.DataFrame.from_dict(response)
df_r
# Out:
#   :@computed_region_92fq_4b7q :@computed_region_efsh_h5xi  \
# 0                         NaN                         NaN
# 1                          37                       17214
# 2                          48                       17615
# 3                          31                       11271
# 4                         NaN                         NaN
#
#   :@computed_region_f5dn_yrer :@computed_region_sbqj_enih  \
# 0                         NaN                         NaN
# 1                          42                          53
# 2                          17                          44
# 3                          58                          26
# 4                         NaN                         NaN
#
#   :@computed_region_yeji_bk3q  address_type agency  \
# 0                         NaN  INTERSECTION    DOT
# 1                           2  INTERSECTION    DOT
# 2                           2     BLOCKFACE    DOT
# 3                           5  INTERSECTION    DOT
# ...

# %%
df
# Out:
#     :@computed_region_92fq_4b7q :@computed_region_efsh_h5xi  \
# 0                           NaN                         NaN
# 1                            37                       17214
# 2                            48                       17615
# 3                            31                       11271
# 4                           NaN                         NaN
# 5                            28                       14786
# 6                           NaN                         NaN
# 7                             4                       14781
# 8                            38                       17619
# 9                            47                       20530
# 10                           39                       13091
# 11                          NaN                         NaN
# 12                           43                       10937
# 13                          NaN                         NaN
# 14                          NaN                         NaN
# ...

# %%
# Out:
#      address_type agency                                        agency_name  \
# 0    INTERSECTION    DOT                       Department of Transportation
# 1         ADDRESS    HPD  Department of Housing Preservation and Develop...
# 2         ADDRESS    HPD  Department of Housing Preservation and Develop...
# 3         ADDRESS    DEP             Department of Environmental Protection
# 4         ADDRESS   NYPD                    New York City Police Department
# 5         ADDRESS   NYPD                    New York City Police Department
# 6         ADDRESS   NYPD                    New York City Police Department
# 7         ADDRESS    DEP             Department of Environmental Protection
# 8         ADDRESS   NYPD                    New York City Police Department
# 9         ADDRESS   NYPD                    New York City Police Department
# 10        ADDRESS   NYPD                    New York City Police Department
# ...
